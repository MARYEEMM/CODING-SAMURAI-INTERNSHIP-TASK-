# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
iris="/content/Iris.csv"
y = ["sepal length","sepal width","petal length","petal width" , "class"]

# %%
data =pd.read_csv(iris,names=y)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head(5)
# Out:
#      sepal length   sepal width   petal length   petal width        class
# Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa

# %%
data = sns.load_dataset('iris').rename(columns={'species': 'class'})

# Diagrama de pares coloreado por la clase
sns.pairplot(data, hue="class")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-15-218701543.py in <cell line: 0>()
#       3 # Diagrama de pares coloreado por la clase
#       4 sns.pairplot(data, hue="class")
# ----> 5 plt.figure(10,5)
#       6 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1040                 RuntimeWarning)
#    1041
# -> 1042         manager = new_figure_manager(
#    1043             num, figsize=figsize, dpi=dpi,
#    1044             facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     550     """Create a new figure manager instance."""
#     551     _warn_if_gui_out_of_main_thread()
# ...

# %%
x=data.drop("class" ,axis=1)
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=data["class"]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: class, Length: 150, dtype: object

# %%
KNN=KNeighborsClassifier(n_neighbors=3)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=KNN.predict(x_test)

# %%
print("accuracy ", accuracy_score(y_test,y_pred))
# Out:
# accuracy  0.9555555555555556

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         9
#   versicolor       0.90      1.00      0.95        18
#    virginica       1.00      0.89      0.94        18
#
#     accuracy                           0.96        45
#    macro avg       0.97      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45

# %%
x_test.head(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 47            4.6          3.2           1.4          0.2
# 119           6.0          2.2           5.0          1.5
# 148           6.2          3.4           5.4          2.3
# 27            5.2          3.5           1.5          0.2
# 108           6.7          2.5           5.8          1.8

# %%
x_train.head(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 18            5.7          3.8           1.7          0.3
# 83            6.0          2.7           5.1          1.6
# 116           6.5          3.0           5.5          1.8
# 63            6.1          2.9           4.7          1.4

# %%
prediction=KNN.predict([[5.1,3.5,1.4,0.2]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
new=pd.DataFrame({"sepal_length":[5.1],"sepal_width":[3.5],"petal_length":[1.4],"petal_width":[0.2]})

# %%
prediction=KNN.predict(new)

# %%
prediction
# Out:
# array(['setosa'], dtype=object)

# %%
pred=KNN.predict([[6.5	,3.0,	5.2	,2.0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
pred
# Out:
# array(['virginica'], dtype=object)
